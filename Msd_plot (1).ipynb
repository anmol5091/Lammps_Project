# %%
import numpy as np
import scipy as sp

# %%
with open('msd_data_0.3.lammps','r') as f:
    msd_data=f.readlines()

# %%
def get_msd_value(msd_data,i):
    l=msd_data[i].split()
    return float(l[7])
#msd function
def msd(msd_data):
    msd_set=[]
    for i in range(0,390,10):
        base_value=get_msd_value(msd_data,i)
        msd_value=[]
        for j in range(i,i+10):
            msd_value.append(get_msd_value(msd_data,j)-base_value)
        msd_set.append(msd_value)
    avg_msd=[]
    for i in range(0,10):
        sum=0
        for j in range(len(msd_set)):
            sum+=msd_set[j][i]
        avg_msd.append(sum/len(msd_set))
    #graph plotting
    import matplotlib.pyplot as plt
    plt.plot(avg_msd)
    plt.show()
msd(msd_data)

# %%
with open('msd_data_0.6.lammps','r') as f:
    msd_data=f.readlines()

# %%
def get_msd_value(msd_data,i):
    l=msd_data[i].split()
    return float(l[7])
#msd function
def msd(msd_data):
    msd_set=[]
    for i in range(0,390,10):
        base_value=get_msd_value(msd_data,i)
        msd_value=[]
        for j in range(i,i+10):
            msd_value.append(get_msd_value(msd_data,j)-base_value)
        msd_set.append(msd_value)
    avg_msd=[]
    for i in range(0,10):
        sum=0
        for j in range(len(msd_set)):
            sum+=msd_set[j][i]
        avg_msd.append(sum/len(msd_set))
    #graph plotting
    import matplotlib.pyplot as plt
    plt.plot(avg_msd)
    plt.show()
msd(msd_data)

# %%
with open('msd_data_0.9.lammps','r') as f:
    msd_data=f.readlines()
    
def get_msd_value(msd_data,i):
    l=msd_data[i].split()
    return float(l[7])
#msd function
def msd(msd_data):
    msd_set=[]
    for i in range(0,390,10):
        base_value=get_msd_value(msd_data,i)
        msd_value=[]
        for j in range(i,i+10):
            msd_value.append(get_msd_value(msd_data,j)-base_value)
        msd_set.append(msd_value)
    avg_msd=[]
    for i in range(0,10):
        sum=0
        for j in range(len(msd_set)):
            sum+=msd_set[j][i]
        avg_msd.append(sum/len(msd_set))
    #graph plotting
    import matplotlib.pyplot as plt
    plt.plot(avg_msd)
    plt.show()
msd(msd_data)

# %%
with open('msd_data_1.2.lammps','r') as f:
    msd_data=f.readlines()
    
def get_msd_value(msd_data,i):
    l=msd_data[i].split()
    return float(l[7])
#msd function
def msd(msd_data):
    msd_set=[]
    for i in range(0,390,10):
        base_value=get_msd_value(msd_data,i)
        msd_value=[]
        for j in range(i,i+10):
            msd_value.append(get_msd_value(msd_data,j)-base_value)
        msd_set.append(msd_value)
    avg_msd=[]
    for i in range(0,10):
        sum=0
        for j in range(len(msd_set)):
            sum+=msd_set[j][i]
        avg_msd.append(sum/len(msd_set))
    #graph plotting
    import matplotlib.pyplot as plt
    plt.plot(avg_msd)
    plt.show()
msd(msd_data)

# %%
with open('msd_data_1.5.lammps','r') as f:
    msd_data=f.readlines()
    
def get_msd_value(msd_data,i):
    l=msd_data[i].split()
    return float(l[7])
#msd function
def msd(msd_data):
    msd_set=[]
    for i in range(0,390,10):
        base_value=get_msd_value(msd_data,i)
        msd_value=[]
        for j in range(i,i+10):
            msd_value.append(get_msd_value(msd_data,j)-base_value)
        msd_set.append(msd_value)
    avg_msd=[]
    for i in range(0,10):
        sum=0
        for j in range(len(msd_set)):
            sum+=msd_set[j][i]
        avg_msd.append(sum/len(msd_set))
    #graph plotting
    import matplotlib.pyplot as plt
    plt.plot(avg_msd)
    plt.show()
msd(msd_data)

# %%
with open('msd_data_1.8.lammps','r') as f:
    msd_data=f.readlines()
    
def get_msd_value(msd_data,i):
    l=msd_data[i].split()
    return float(l[7])
#msd function
def msd(msd_data):
    msd_set=[]
    for i in range(0,390,10):
        base_value=get_msd_value(msd_data,i)
        msd_value=[]
        for j in range(i,i+10):
            msd_value.append(get_msd_value(msd_data,j)-base_value)
        msd_set.append(msd_value)
    avg_msd=[]
    for i in range(0,10):
        sum=0
        for j in range(len(msd_set)):
            sum+=msd_set[j][i]
        avg_msd.append(sum/len(msd_set))
    #graph plotting
    import matplotlib.pyplot as plt
    plt.plot(avg_msd)
    plt.show()
msd(msd_data)

# %%
with open('msd_data_2.1.lammps','r') as f:
    msd_data=f.readlines()
    
def get_msd_value(msd_data,i):
    l=msd_data[i].split()
    return float(l[7])
#msd function
def msd(msd_data):
    msd_set=[]
    for i in range(10,390,10):
        base_value=get_msd_value(msd_data,i)
        msd_value=[]
        for j in range(i,i+10):
            msd_value.append(get_msd_value(msd_data,j)-base_value)
        msd_set.append(msd_value)
    avg_msd=[]
    for i in range(0,10):
        sum=0
        for j in range(len(msd_set)):
            sum+=msd_set[j][i]
        avg_msd.append(sum/len(msd_set))
    #graph plotting
    import matplotlib.pyplot as plt
    plt.plot(avg_msd)
    plt.show()
msd(msd_data)

# %%
with open('msd_data_2.4.lammps','r') as f:
    msd_data=f.readlines()
    
def get_msd_value(msd_data,i):
    l=msd_data[i].split()
    return float(l[7])
#msd function
def msd(msd_data):
    msd_set=[]
    for i in range(10,390,10):
        base_value=get_msd_value(msd_data,i)
        msd_value=[]
        for j in range(i,i+10):
            msd_value.append(get_msd_value(msd_data,j)-base_value)
        msd_set.append(msd_value)
    avg_msd=[]
    for i in range(0,10):
        sum=0
        for j in range(len(msd_set)):
            sum+=msd_set[j][i]
        avg_msd.append(sum/len(msd_set))
    #graph plotting
    import matplotlib.pyplot as plt
    plt.plot(avg_msd)
    plt.show()
msd(msd_data)

# %%
with open('msd_data.2.7.lammps','r') as f:
    msd_data=f.readlines()
    
def get_msd_value(msd_data,i):
    l=msd_data[i].split()
    return float(l[7])
#msd function
def msd(msd_data):
    msd_set=[]
    for i in range(10,390,10):
        base_value=get_msd_value(msd_data,i)
        msd_value=[]
        for j in range(i,i+10):
            msd_value.append(get_msd_value(msd_data,j)-base_value)
        msd_set.append(msd_value)
    avg_msd=[]
    for i in range(0,10):
        sum=0
        for j in range(len(msd_set)):
            sum+=msd_set[j][i]
        avg_msd.append(sum/len(msd_set))
    #graph plotting
    import matplotlib.pyplot as plt
    plt.plot(avg_msd)
    plt.show()
msd(msd_data)

# %%
with open('msd_data_3.0.lammps','r') as f:
    msd_data=f.readlines()
    
def get_msd_value(msd_data,i):
    l=msd_data[i].split()
    return float(l[7])
#msd function
def msd(msd_data):
    msd_set=[]
    for i in range(10,390,10):
        base_value=get_msd_value(msd_data,i)
        msd_value=[]
        for j in range(i,i+10):
            msd_value.append(get_msd_value(msd_data,j)-base_value)
        msd_set.append(msd_value)
    avg_msd=[]
    for i in range(0,10):
        sum=0
        for j in range(len(msd_set)):
            sum+=msd_set[j][i]
        avg_msd.append(sum/len(msd_set))
    #graph plotting
    import matplotlib.pyplot as plt
    plt.plot(avg_msd)
    plt.show()
msd(msd_data)
